# %%
print("HOla")
print(" Amigo")
# Out:
# HOla Amigo

# %%
println("Hello")
println("Mate")
# Out:
# Hello
# Mate

# %%
my_pi = 3.1459
# Out:
# 3.1459

# %%
typeof(my_pi)
# Out:
# Float64

# %%
10 ^ 2
# Out:
# 100

# %%
i = Complex(0,1)
# Out:
# 0 + 1im

# %%
10 ^ i
# Out:
# -0.6682015101903132 + 0.7439803369574931im

# %%
i ^ i
# Out:
# 0.20787957635076193 + 0.0im

# %%
i^i^i^i^i^i^pi
# Out:
# 0.26331558461978777 + 0.0407539842241043im

# %%
pi
# Out:
# π = 3.1415926535897...

# %%
print(" Hello Pi is $pi and 2 Pi is $(pi*2)")
# Out:
#  Hello Pi is π and 2 Pi is 6.283185307179586

# %%
n = 0
while n < 10
    n = n + 1
    println("n is $n")
end
# Out:
# n is 1
# n is 2
# n is 3
# n is 4
# n is 5
# n is 6
# n is 7
# n is 8
# n is 9
# n is 10

# %%
for i in 1:10
    println("I is $i")
end
# Out:
# I is 1
# I is 2
# I is 3
# I is 4
# I is 5
# I is 6
# I is 7
# I is 8
# I is 9
# I is 10

# %%
for i ∈ 1:10
    println("I is $i")
end
# Out:
# I is 1
# I is 2
# I is 3
# I is 4
# I is 5
# I is 6
# I is 7
# I is 8
# I is 9
# I is 10

# %%
[i|j for i ∈ 1:10, j ∈ 1:10]
# Out:
# 10×10 Array{Int64,2}:
#   1   3   3   5   5   7   7   9   9  11
#   3   2   3   6   7   6   7  10  11  10
#   3   3   3   7   7   7   7  11  11  11
#   5   6   7   4   5   6   7  12  13  14
#   5   7   7   5   5   7   7  13  13  15
#   7   6   7   6   7   6   7  14  15  14
#   7   7   7   7   7   7   7  15  15  15
#   9  10  11  12  13  14  15   8   9  10
#   9  11  11  13  13  15  15   9   9  11
#  11  10  11  14  15  14  15  10  11  10

# %%
if !true
    println("True")
elseif !true
    println("Blah")
else
    println("Hola")
end
# Out:
# Hola

# %%
x, y = 10, 20
# Out:
# (10, 20)

# %%
if x > y
    x
else
    y
end
# Out:
# 20

# %%
x > y ? x : y
# Out:
# 20

# %%
(x > y) && println("x > y")
# Out:
# false

# %%
(x < y) && println("x < y")
# Out:
# x < y

# %%
function sayhi(name)
    println("Hello $name")
end
# Out:
# sayhi (generic function with 1 method)

# %%
sayhi("Paul")
# Out:
# Hello Paul

# %%
mosey(hi) = println("Hello Mosey $hi")
# Out:
# mosey (generic function with 1 method)

# %%
mosey("How are you")
# Out:
# Hello Mosey How are you

# %%
hoya = lol -> print("it says $lol lol")
# Out:
# #7 (generic function with 1 method)

# %%
hoya("Byeee")
# Out:
# it says Byeee lol

# %%
hoy = randn(5,5)
# Out:
# 5×5 Array{Float64,2}:
#   0.0108758  -0.208481   0.918922   1.51495   -0.53972
#  -0.219352    0.886817  -0.203044  -1.50208   -1.37056
#   0.947307    0.872703   1.47585   -0.232838  -0.758748
#   0.352834    0.195822   0.516645  -0.107294  -0.245733
#  -0.0736822  -0.342269   1.57762   -0.202651  -0.0434652

# %%
(hoy^2 .+ 5)
# Out:
# 5×5 Array{Float64,2}:
#  6.49064  6.09618  6.33973  5.0625   4.23382
#  4.18175  5.82994  1.38043  3.82181  4.48569
#  6.19071  7.07851  6.55412  4.95937  2.26302
#  5.43055  5.61407  5.60385  5.1814   4.18622
#  6.50047  6.06382  7.15685  5.06571  4.36354

# %%
#= 
This has the same stuff as Matlab Lol
=#

# %%
sort(hoy[1,:])
# Out:
# 5-element Array{Float64,1}:
#  -0.5397202710334998
#  -0.20848050690685793
#   0.0108757848885749
#   0.9189215722820409
#   1.5149524690833196

# %%
sort!(hoy[1,:]) # modifier!!!
# Out:
# 5-element Array{Float64,1}:
#  -0.5397202710334998
#  -0.20848050690685793
#   0.0108757848885749
#   0.9189215722820409
#   1.5149524690833196

# %%
hoy[1,:]
# Out:
# 5-element Array{Float64,1}:
#   0.0108757848885749
#  -0.20848050690685793
#   0.9189215722820409
#   1.5149524690833196
#  -0.5397202710334998

# %%
lo = [i + 3*j for j ∈ 0:2, i ∈ 1:3]
# Out:
# 3×3 Array{Int64,2}:
#  1  2  3
#  4  5  6
#  7  8  9

# %%
lo^2
# Out:
# 3×3 Array{Int64,2}:
#   30   36   42
#   66   81   96
#  102  126  150

# %%
lo .^ 2
# Out:
# 3×3 Array{Int64,2}:
#   1   4   9
#  16  25  36
#  49  64  81

# %%
lo[1,:]
# Out:
# 3-element Array{Int64,1}:
#  1
#  2
#  3

# %%
# Same as Matlab lolllll

# %%
import Pkg
Pkg.add("Example")
Pkg.add("Colors")
Pkg.add("Plots")
Pkg.add("PlotlyJS")
Pkg.add("ORCA")
# Out:
#    Updating registry at `~/.juliapro/JuliaPro_v1.4.2-1/registries/JuliaPro`
#   Resolving package versions...
#   Installed Example ─ v0.5.3
#    Updating `~/.juliapro/JuliaPro_v1.4.2-1/environments/v1.4/Project.toml`
#   [7876af07] + Example v0.5.3
#    Updating `~/.juliapro/JuliaPro_v1.4.2-1/environments/v1.4/Manifest.toml`
#   [7876af07] + Example v0.5.3
#   Resolving package versions...
#    Updating `~/.juliapro/JuliaPro_v1.4.2-1/environments/v1.4/Project.toml`
#   [5ae59095] + Colors v0.12.2
#    Updating `~/.juliapro/JuliaPro_v1.4.2-1/environments/v1.4/Manifest.toml`
#  [no changes]
#   Resolving package versions...
#   Installed x264_jll ────────── v2019.5.25+2
#   Installed PlotUtils ───────── v1.0.5
#   Installed Opus_jll ────────── v1.3.1+1
#   Installed Showoff ─────────── v0.3.1
#   Installed Ogg_jll ─────────── v1.3.4+0
#   Installed Bzip2_jll ───────── v1.0.6+2
#   Installed StaticArrays ────── v0.12.3
#   Installed RecipesBase ─────── v1.0.1
# ...

# %%
using Example
# Out:
# ArgumentError: Package Example not found in current path:
# - Run `import Pkg; Pkg.add("Example")` to install the Example package.
#
#
# Stacktrace:
#  [1] require(::Module, ::Symbol) at ./loading.jl:892
#  [2] top-level scope at In[39]:1

# %%
hello("it's me. I was wondering if after all these years you'd like to meet")
# Out:
# "Hello, it's me. I was wondering if after all these years you'd like to meet"

# %%
using Colors

# %%
palette = distinguishable_colors(1000)
# Out:
# 1000-element Array{RGB{N0f8},1} with eltype RGB{FixedPointNumbers.Normed{UInt8,8}}:
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(1.0,1.0,0.455)
#  RGB{N0f8}(1.0,0.608,1.0)
#  RGB{N0f8}(0.0,0.827,1.0)
#  RGB{N0f8}(0.886,0.388,0.051)
#  RGB{N0f8}(0.0,0.494,0.0)
#  RGB{N0f8}(0.0,0.314,0.902)
#  RGB{N0f8}(0.675,0.0,0.278)
#  RGB{N0f8}(0.0,1.0,0.784)
#  RGB{N0f8}(0.0,0.392,0.408)
#  RGB{N0f8}(1.0,0.835,0.769)
#  RGB{N0f8}(0.424,0.322,0.0)
#  RGB{N0f8}(0.478,0.459,0.506)
#  ⋮
#  RGB{N0f8}(0.667,0.608,0.463)
#  RGB{N0f8}(0.275,0.333,0.42)
#  RGB{N0f8}(0.729,0.682,0.584)
#  RGB{N0f8}(0.804,0.757,0.659)
#  RGB{N0f8}(0.341,0.4,0.49)
#  RGB{N0f8}(0.557,0.616,0.71)
#  RGB{N0f8}(0.631,0.69,0.788)
#  RGB{N0f8}(0.675,0.769,0.918)
#  RGB{N0f8}(0.784,0.843,0.945)
#  RGB{N0f8}(0.518,1.0,0.796)
#  RGB{N0f8}(0.102,0.38,0.161)
#  RGB{N0f8}(0.0,0.529,0.733)

# %%
rand(palette, 100, 100)
# Out:
# 100×100 Array{RGB{N0f8},2} with eltype RGB{FixedPointNumbers.Normed{UInt8,8}}:
#  RGB{N0f8}(0.878,0.18,0.337)   …  RGB{N0f8}(0.0,0.008,0.137)
#  RGB{N0f8}(0.318,0.161,0.067)     RGB{N0f8}(0.757,0.792,0.286)
#  RGB{N0f8}(0.545,0.549,0.349)     RGB{N0f8}(0.161,0.0,0.004)
#  RGB{N0f8}(0.51,0.918,0.737)      RGB{N0f8}(0.655,0.914,0.384)
#  RGB{N0f8}(0.925,0.588,0.69)      RGB{N0f8}(0.573,0.529,0.49)
#  RGB{N0f8}(0.561,0.522,0.616)  …  RGB{N0f8}(0.678,0.596,0.518)
#  RGB{N0f8}(0.427,0.306,0.157)     RGB{N0f8}(0.541,0.706,0.831)
#  RGB{N0f8}(0.0,0.894,0.557)       RGB{N0f8}(0.333,0.235,0.29)
#  RGB{N0f8}(0.345,0.569,0.655)     RGB{N0f8}(0.063,0.082,0.157)
#  RGB{N0f8}(0.176,0.137,0.0)       RGB{N0f8}(0.6,0.435,0.239)
#  RGB{N0f8}(0.443,0.337,0.663)  …  RGB{N0f8}(0.875,0.0,0.651)
#  RGB{N0f8}(0.4,0.408,0.216)       RGB{N0f8}(0.533,0.0,0.631)
#  RGB{N0f8}(0.71,0.6,0.247)        RGB{N0f8}(0.918,0.31,0.549)
#  ⋮                             ⋱
# ...

# %%
using Plots

# %%
x = -3:0.1:3
f(x) = x^2

y = f.(x);

# %%
gr()
# Out:
# Plots.GRBackend()

# %%
plot(x, y, label="line")
scatter!(x, y, label="points")
